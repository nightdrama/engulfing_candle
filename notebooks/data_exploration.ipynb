# %%
import os
import sys

# go up to project root
os.chdir("..")
sys.path.append(os.getcwd())

from src.data.stock_lists import get_sp500_symbols

# %%
sp500_symbols = get_sp500_symbols()
sp500_symbols
# Out:
# Successfully fetched 148 S&P 500 symbols
# ['APRP',
#  'AUGP',
#  'BUFP',
#  'CATH',
#  'CPSA',
#  'CPSD',
#  'CPSF',
#  'CPSJ',
#  'CPSL',
#  'CPSM',
#  'CPSN',
#  'CPSO',
#  'CPSP',
#  'CPSR',
#  'CPST',
#  'CPSU',
#  'CPSY',
#  'DECP',
#  'DIVG',
#  'DSPY',
#  'EFIV',
#  'EGLE',
#  'EMOT',
#  'FB',
#  'FCFY',
#  'FEBP',
#  'FLAG',
#  'GPIX',
#  'HIBL',
#  'HIBS',
#  'ISPY',
#  'IVE',
#  'IVV',
#  'IVVW',
#  'IVW',
#  'JANP',
#  'JULP',
#  'JUNP',
#  'KNG',
#  'KNGZ',
#  'LCOW',
#  'MAYP',
#  'MRCP',
#  'NOBL',
#  'NOVP',
#  'OCTP',
#  'OOSB',
#  'PBAP',
#  'PBAU',
#  'PBDE',
#  'PBFB',
#  'PBFR',
#  'PBJA',
#  'PBJL',
#  'PBJN',
#  'PBMR',
#  'PBMY',
#  'PBNV',
#  'PBOC',
#  'PBSE',
#  'PHDG',
#  'PMAP',
#  'PMAU',
#  'PMFB',
#  'PMJA',
#  'PMJL',
#  'PMJN',
#  'PMMR',
#  'PMMY',
#  'PUTD',
#  'QDCC',
#  'QDIV',
#  'QVML',
#  'RPG',
#  'RPV',
#  'RSP',
#  'RSPA',
#  'RSPC',
#  'RSPD',
#  'RSPE',
#  'RSPF',
#  'RSPG',
#  'RSPH',
#  'RSPM',
#  'RSPN',
#  'RSPR',
#  'RSPS',
#  'RSPT',
#  'RSPU',
#  'RWL',
#  'SDTY',
#  'SEPP',
#  'SNPE',
#  'SNPG',
#  'SNPV',
#  'SPDN',
#  'SPDV',
#  'SPGP',
#  'SPHB',
#  'SPHD',
#  'SPHQ',
#  'SPLG',
#  'SPLV',
#  'SPMO',
#  'SPMV',
#  'SPUS',
#  'SPUU',
#  'SPVM',
#  'SPVU',
#  'SPXD',
#  'SPXE',
#  'SPXL',
#  'SPXN',
#  'SPXS',
#  'SPXT',
#  'SPXU',
#  'SPXV',
#  'SPXX',
#  'SPY',
#  'SPYD',
#  'SPYG',
#  'SPYH',
#  'SPYI',
#  'SPYT',
#  'SPYU',
#  'SPYV',
#  'SPYX',
#  'TOPC',
#  'UPRO',
#  'VOO',
#  'VOOG',
#  'VOOV',
#  'VXX',
#  'VXZ',
#  'WDTE',
#  'XCLR',
#  'XDIV',
#  'XDTE',
#  'XLG',
#  'XOEF',
#  'XPAY',
#  'XRLV',
#  'XRMI',
#  'XTR',
#  'XVV',
#  'XYLD',
#  'XYLG',
#  'ZZZ']
